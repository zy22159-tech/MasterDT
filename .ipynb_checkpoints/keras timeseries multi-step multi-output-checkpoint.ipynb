# %%
# https://www.kaggle.com/code/nicapotato/keras-timeseries-multi-step-multi-output/notebook
import tensorflow as tf
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import time
import gc
import sys

mpl.rcParams['figure.figsize'] = (17, 5)
mpl.rcParams['axes.grid'] = False
sns.set_style("whitegrid")

notebookstart= time.time()
# Out:
# Tensorflow Version: 2.9.1
# Pandas Version: 1.4.2
# Numpy Version: 1.21.5
# System Version: 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]

# %%
# Data Loader Parameters
BATCH_SIZE = 32
BUFFER_SIZE = 10000

# LSTM Parameters
EVALUATION_INTERVAL = 200
EPOCHS = 4
PATIENCE = 5

# Reproducibility
SEED = 13
tf.random.set_seed(SEED)

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv ('Data/weekly_features.csv')
df = df.drop (columns = ['Unnamed: 0','USD_PHP Historical Data.csv'])
dates = df.year*100+df.week
df['Date'] = pd.to_datetime(dates.astype(str) + '0', format='%Y%W%w')
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
mask = (df['Date'] >'1990-09-30') & (df['Date'] <= '2021-09-30')
df= df.loc[mask]
df = df.fillna(method='ffill')

# %%
def convert_to_timestamp(x):
    """Convert date objects to integers"""
    return time.mktime(x.to_datetime().timetuple())

# %%
# https://www.aiproblog.com/index.php/2018/08/21/4-common-machine-learning-data-transforms-for-time-series-forecasting/
# difference dataset
diff_df=df.drop(columns=['Date', 'year', 'week'])
diff_df = diff_df.diff()
diff_df = diff_df.iloc[1:]
#diff_df['year']=df.year[1:]
#diff_df['week']=df.year[1:]
diff_df['Date']=df.Date[1:]
diff_df['Date'] = pd.to_datetime(diff_df['Date'])
# convert date to timestamp
diff_df['Date'] = diff_df['Date'].map(pd.Timestamp.timestamp)

# %%
#split the data into training and testing dataset
column_indices = {name: i for i, name in enumerate(diff_df.columns)}

n = len(diff_df)
train_df = diff_df[0:int(n*0.7)]
val_df = diff_df[int(n*0.7):int(n*0.9)]
test_df = diff_df[int(n*0.9):]

num_features = diff_df.shape[1]

# %%
#Normalize the data
from sklearn.preprocessing import MinMaxScaler
#col_list = [i for i in diff_df.columns if i != 'Date']
scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(train_df)
scaled_val = scaler.transform(val_df)
scaled_test = scaler.transform(test_df)

# %% [markdown]
# ### Make Dataset

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 24
future_target = 1
STEP = 1

x_train_single, y_train_single = multivariate_data(scaled_train, scaled_train[:, 8], 0,
                                                   None, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(scaled_val, scaled_val[:, 8],
                                               0, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
past_history = 24
future_target = 24
STEP = 1

x_train_multi, y_train_multi = multivariate_data(scaled_train, scaled_train[:, 8], 0,
                                                   None, past_history,
                                                   future_target, STEP,
                                                   single_step=False)
x_val_multi, y_val_multi = multivariate_data(scaled_val, scaled_val[:, 8],
                                               0, None, past_history,
                                               future_target, STEP,
                                               single_step=False)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %% [markdown]
# ### Plot function

# %% [markdown]
# #### Plot training loss

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

# %% [markdown]
# ### plot prediction

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                   label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
        plt.legend()
        plt.xlim([time_steps[0], (future+5)*2])
        plt.xlabel('Time-Step')
    
    return plt

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(18, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %% [markdown]
# ### LSTM model

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %%
print(f"Evaluation Threshold: {EVALUATION_INTERVAL}",
      f"Epochs: {EPOCHS}", sep="\n")

early_stopping = EarlyStopping(monitor='val_loss', patience = 3, restore_best_weights=True)
single_step_history = single_step_model.fit(train_data_single,
                                            epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            callbacks=[early_stopping],
                                            validation_steps=50)
# Out:
# Evaluation Threshold: 200
# Epochs: 4
# Epoch 1/4
# 200/200 [==============================] - 2s 5ms/step - loss: 0.0657 - val_loss: 0.0705
# Epoch 2/4
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0570 - val_loss: 0.0575
# Epoch 3/4
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0555 - val_loss: 0.0574
# Epoch 4/4
# 200/200 [==============================] - 1s 4ms/step - loss: 0.0541 - val_loss: 0.0576

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %%
for x, y in val_data_single.take(1):
    plot = show_plot([x[0][:, 8].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 1,
                   'Single Step Prediction')
    plot.show()
# Out:
# 1/1 [==============================] - 0s 3ms/step

# %% [markdown]
# #### CNN-LSTM

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed, Conv1D, MaxPooling1D, Flatten, Bidirectional, Input, Flatten, Activation, Reshape, RepeatVector, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(past_history,num_features)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(RepeatVector(future_target))
model.add(Bidirectional(LSTM(200, activation='relu', return_sequences=True)))
model.add(TimeDistributed(Dense(100, activation='relu')))
model.add(TimeDistributed(Dense(1)))
model.summary()
model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 22, 64)            3328
#
#  conv1d_13 (Conv1D)          (None, 20, 64)            12352
#
#  max_pooling1d_6 (MaxPooling  (None, 10, 64)           0
#  1D)
#
#  flatten_6 (Flatten)         (None, 640)               0
#
#  repeat_vector_5 (RepeatVect  (None, 24, 640)          0
#  or)
#
#  bidirectional (Bidirectiona  (None, 24, 400)          1345600
#  l)
#
#  time_distributed_10 (TimeDi  (None, 24, 100)          40100
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 24, 1)            101
#  stributed)
#
# =================================================================
# Total params: 1,401,481
# Trainable params: 1,401,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience = 3, restore_best_weights=True)
multi_step_history = model.fit(train_data_multi,
                                          epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=EVALUATION_INTERVAL,
                                          callbacks=[early_stopping])
# Out:
# Epoch 1/4
# 200/200 [==============================] - 12s 58ms/step - loss: 0.0549 - val_loss: 0.0558
# Epoch 2/4
# 200/200 [==============================] - 11s 57ms/step - loss: 0.0552 - val_loss: 0.0562
# Epoch 3/4
# 200/200 [==============================] - 11s 57ms/step - loss: 0.0553 - val_loss: 0.0553
# Epoch 4/4
# 200/200 [==============================] - 11s 57ms/step - loss: 0.0540 - val_loss: 0.0554

# %%
### Multistep Multioutput prediction

# %%
def multivariate_multioutput_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data)[:,:,:,np.newaxis,np.newaxis], np.array(labels)[:,:,:,np.newaxis,np.newaxis]

def multi_step_output_plot(history, true_future, prediction):
    plt.figure(figsize=(18, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)
    
    for i, (var, c) in enumerate(zip(df.columns[7:11], ['b','r'])):
        plt.plot(num_in, np.array(history[:, i]), c, label=var)
        plt.plot(np.arange(num_out)/STEP, np.array(true_future[:,i]), c+'o', markersize=5, alpha=0.5,
               label=f"True {var.title()}")
        if prediction.any():
            plt.plot(np.arange(num_out)/STEP, np.array(prediction[:,i]), '*', markersize=5, alpha=0.5,
                     label=f"Predicted {var.title()}")
    
    plt.legend(loc='upper left')
    plt.show()

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential

# %%
def CNN_LSTM_model(input_timesteps, output_timesteps, num_links, num_inputs):    
    model = Sequential()
    model.add(BatchNormalization(name = 'batch_norm_0', input_shape = (input_timesteps, num_inputs, 1, 1)))
    model.add(ConvLSTM2D(name ='conv_lstm_1',
                         filters = 64, kernel_size = (10, 1),                       
                         padding = 'same', 
                         return_sequences = False))
    
    model.add(Dropout(0.30, name = 'dropout_1'))
    model.add(BatchNormalization(name = 'batch_norm_1'))

#     model.add(ConvLSTM2D(name ='conv_lstm_2',
#                          filters = 64, kernel_size = (5, 1), 
#                          padding='same',
#                          return_sequences = False))
    
#     model.add(Dropout(0.20, name = 'dropout_2'))
#     model.add(BatchNormalization(name = 'batch_norm_2'))
    
    model.add(Flatten())
    model.add(RepeatVector(output_timesteps))
    model.add(Reshape((output_timesteps, num_inputs, 1, 64)))
    
#     model.add(ConvLSTM2D(name ='conv_lstm_3',
#                          filters = 64, kernel_size = (10, 1), 
#                          padding='same',
#                          return_sequences = True))
    
#     model.add(Dropout(0.20, name = 'dropout_3'))
#     model.add(BatchNormalization(name = 'batch_norm_3'))
    
    model.add(ConvLSTM2D(name ='conv_lstm_4',
                         filters = 64, kernel_size = (5, 1), 
                         padding='same',
                         return_sequences = True))
    
    model.add(TimeDistributed(Dense(units=1, name = 'dense_1', activation = 'relu')))
    model.add(Dense(units=1, name = 'dense_2'))

#     optimizer = RMSprop() #lr=0.0001, rho=0.9, epsilon=1e-08, decay=0.9)
#     optimizer = tf.keras.optimizers.Adam(0.1)
    optimizer = tf.keras.optimizers.RMSprop(leanring_rate=0.003, clipvalue=1.0)
    model.compile(loss = "mse", optimizer = optimizer, metrics = ['mae', 'mse'])
    return model

# %%
# Extend Prediction Window..
future_target = 10
past_history = 144
x_train_multi, y_train_multi = multivariate_multioutput_data(scaled_train[:,7:11], scaled_train[:,7:11], 0,
                                                 None, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_multioutput_data(scaled_val [:,7:11], scaled_val[:, 7:11],
                                             0, None, past_history,
                                             future_target, STEP)

BATCH_SIZE = 32

train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
EPOCHS = 10
steps_per_epoch = 10
validation_steps = 50

modelstart = time.time()
early_stopping = EarlyStopping(monitor='val_loss', patience = PATIENCE, restore_best_weights=True)
model = CNN_LSTM_model (x_train_multi.shape[1], future_target, y_train_multi.shape[2], x_train_multi.shape[2])
print(model.summary())

# Train
print("\nTRAIN MODEL...")
history = model.fit(train_data_multi,
                    epochs = EPOCHS,
                    validation_data=val_data_multi,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps,
                    verbose=1,
                    callbacks=[early_stopping])
model.save('multi-output-timesteps.h5')
print("\nModel Runtime: %0.2f Minutes"%((time.time() - modelstart)/60))
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_norm_0 (BatchNormaliz  (None, 144, 4, 1, 1)     4
#  ation)
#
#  conv_lstm_1 (ConvLSTM2D)    (None, 4, 1, 64)          166656
#
#  dropout_1 (Dropout)         (None, 4, 1, 64)          0
#
#  batch_norm_1 (BatchNormaliz  (None, 4, 1, 64)         256
#  ation)
#
#  flatten_10 (Flatten)        (None, 256)               0
#
#  repeat_vector_9 (RepeatVect  (None, 10, 256)          0
#  or)
#
#  reshape_3 (Reshape)         (None, 10, 4, 1, 64)      0
#
#  conv_lstm_4 (ConvLSTM2D)    (None, 10, 4, 1, 64)      164096
#
#  time_distributed_15 (TimeDi  (None, 10, 4, 1, 1)      65
#  stributed)
#
#  dense_2 (Dense)             (None, 10, 4, 1, 1)       2
#
# =================================================================
# Total params: 331,079
# Trainable params: 330,949
# Non-trainable params: 130
# _________________________________________________________________
# None
#
# TRAIN MODEL...
# Epoch 1/10
# C:\Users\wangz\Anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# 10/10 [==============================] - 24s 2s/step - loss: 0.2807 - mae: 0.3897 - mse: 0.2807 - val_loss: 0.2081 - val_mae: 0.3911 - val_mse: 0.2081
# Epoch 2/10
# 10/10 [==============================] - 21s 2s/step - loss: 0.1743 - mae: 0.3381 - mse: 0.1743 - val_loss: 0.0620 - val_mae: 0.1766 - val_mse: 0.0620
# Epoch 3/10
# 10/10 [==============================] - 21s 2s/step - loss: 0.0602 - mae: 0.1724 - mse: 0.0602 - val_loss: 0.0612 - val_mae: 0.1855 - val_mse: 0.0612
# Epoch 4/10
# 10/10 [==============================] - 22s 2s/step - loss: 0.0553 - mae: 0.1733 - mse: 0.0553 - val_loss: 0.0518 - val_mae: 0.1639 - val_mse: 0.0518
# Epoch 5/10
# 10/10 [==============================] - 23s 2s/step - loss: 0.0479 - mae: 0.1530 - mse: 0.0479 - val_loss: 0.0483 - val_mae: 0.1638 - val_mse: 0.0483
# Epoch 6/10
# 10/10 [==============================] - 23s 2s/step - loss: 0.0479 - mae: 0.1678 - mse: 0.0479 - val_loss: 0.0417 - val_mae: 0.1501 - val_mse: 0.0417
# Epoch 7/10
# 10/10 [==============================] - 22s 2s/step - loss: 0.0417 - mae: 0.1558 - mse: 0.0417 - val_loss: 0.0407 - val_mae: 0.1580 - val_mse: 0.0407
# Epoch 8/10
# 10/10 [==============================] - 23s 2s/step - loss: 0.0402 - mae: 0.1584 - mse: 0.0402 - val_loss: 0.0386 - val_mae: 0.1577 - val_mse: 0.0386
# Epoch 9/10
# 10/10 [==============================] - 23s 2s/step - loss: 0.0365 - mae: 0.1510 - mse: 0.0365 - val_loss: 0.0356 - val_mae: 0.1498 - val_mse: 0.0356
# Epoch 10/10
# 10/10 [==============================] - 22s 2s/step - loss: 0.0357 - mae: 0.1536 - mse: 0.0357 - val_loss: 0.0336 - val_mae: 0.1450 - val_mse: 0.0336
#
# Model Runtime: 3.73 Minutes

# %%
plot_train_history(history, 'Multi-Step, Multi-Output Training and validation loss')

# %%
for x, y in val_data_multi.take(1):
    multi_step_output_plot(np.squeeze(x[0]), np.squeeze(y[0]), np.squeeze(model.predict(x[0][np.newaxis,:,:,:,:])))
# Out:
# 1/1 [==============================] - 0s 300ms/step
